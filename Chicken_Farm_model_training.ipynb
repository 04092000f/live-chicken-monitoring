# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.5/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DaxyhwwmIH4PJyijs0q4")
project = rf.workspace("furqan-sayyed-5hshj").project("poultry-health-monitoring-l75jt")
version = project.version(8)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to poultry-health-monitoring-8 in yolov11:: 100%|██████████| 8270/8270 [00:03<00:00, 2698.62it/s]

# %%
# !yolo task=detect mode=train model=yolo11s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True batch=32
# Out:
# ...
# 100% 18.4M/18.4M [00:00<00:00, 222MB/s]
# New https://pypi.org/project/ultralytics/8.3.174 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !gdown --id 1mFeu2uR53ylpQZ1buFq8yrcdC2lotbVP
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1mFeu2uR53ylpQZ1buFq8yrcdC2lotbVP
# To: /content/chicken_video.mp4
# 100% 68.1M/68.1M [00:01<00:00, 47.0MB/s]

# %%
workspace = rf.workspace("furqan-sayyed-5hshj")

workspace.deploy_model(
    model_type="yolov11",  # Type of the model
    model_path="/content/runs/detect/train/",  # Path to model directory
    project_ids=["poultry-health-monitoring-l75jt"],  # List of project IDs
    model_name="modelv4",  # Name for the model (must have at least 1 letter, and accept numbers and dashes)
    filename="weights/best.pt"  # Path to weights file (default)
)
# Out:
# loading Roboflow workspace...
# View the status of your deployment for project poultry-health-monitoring-l75jt at: https://app.roboflow.com/furqan-sayyed-5hshj/poultry-health-monitoring-l75jt/models

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" source="/content/chicken_video.mp4" conf=0.6
# Out:
# Ultralytics 8.3.40 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11s summary (fused): 238 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
#
# video 1/1 (frame 1/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 78.9ms
# video 1/1 (frame 2/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 16.7ms
# video 1/1 (frame 3/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 14.6ms
# video 1/1 (frame 4/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 11.5ms
# video 1/1 (frame 5/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 11.2ms
# video 1/1 (frame 6/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 11.0ms
# video 1/1 (frame 7/1818) /content/chicken_video.mp4: 384x640 4 chickens, 4 guinea-fowl-gray-s, 11.0ms
# ...
